# %%
import warnings
warnings.filterwarnings("ignore")

import ast
import os
import json
import pandas as pd
import torch
import importlib
import cv2 

from shutil import copyfile
from tqdm.notebook import tqdm
tqdm.pandas()
from sklearn.model_selection import GroupKFold
from PIL import Image
from string import Template
from IPython.display import display

TRAIN_PATH = 'dataset'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-abc27d7f0e20> in <module>
#       6 import json
#       7 import pandas as pd
# ----> 8 import torch
#       9 import importlib
#      10 import cv2
#
# ModuleNotFoundError: No module named 'torch'

# %%
# check Torch and CUDA version
print(f"Torch: {torch.__version__}")
# !nvcc --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-46d5fd122c22> in <module>
#       1 # check Torch and CUDA version
# ----> 2 print(f"Torch: {torch.__version__}")
#       3 get_ipython().system('nvcc --version')
#
# NameError: name 'torch' is not defined

# %%
def get_bbox(annots):
    bboxes = [list(annot.values()) for annot in annots]
    return bboxes

def get_path(row):
    row['image_path'] = f'{TRAIN_PATH}/train_images/video_{row.video_id}/{row.video_frame}.jpg'
    return row

# %%
df = pd.read_csv("/media/ken/01D7D016D3925700/kaggle/YOLOX/dataset/train.csv")
df.head(5)
# Out:
#    video_id  sequence  video_frame  sequence_frame image_id annotations
# 0         0     40258            0               0      0-0          []
# 1         0     40258            1               1      0-1          []
# 2         0     40258            2               2      0-2          []
# 3         0     40258            3               3      0-3          []
# 4         0     40258            4               4      0-4          []

# %%
# Taken only annotated photos
df["num_bbox"] = df['annotations'].apply(lambda x: str.count(x, 'x'))
df_train = df[df["num_bbox"]>0]

#Annotations 
df_train['annotations'] = df_train['annotations'].progress_apply(lambda x: ast.literal_eval(x))
df_train['bboxes'] = df_train.annotations.progress_apply(get_bbox)

#Images resolution
df_train["width"] = 1280
df_train["height"] = 720

#Path of images
df_train = df_train.progress_apply(get_path, axis=1)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4919.0), HTML(value='')))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-2b0e9c94a85f> in <module>
#       4
#       5 #Annotations
# ----> 6 df_train['annotations'] = df_train['annotations'].progress_apply(lambda x: ast.literal_eval(x))
#       7 df_train['bboxes'] = df_train.annotations.progress_apply(get_bbox)
#       8
#
# /media/ken/01D7D016D3925700/ubuntu_conda/lib/python3.8/site-packages/tqdm/std.py in inner(df, func, *args, **kwargs)
#     779
#     780                 try:
# --> 781                     func = df._is_builtin_func(func)
#     782                 except TypeError:
#     783                     pass
#
# /media/ken/01D7D016D3925700/ubuntu_conda/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485             object.__setattr__(self, name, value)
#    5486         elif name in self._metadata:
# -> 5487             object.__setattr__(self, name, value)
#    5488         else:
#    5489             try:
#
# AttributeError: 'Series' object has no attribute '_is_builtin_func'

# %%
kf = GroupKFold(n_splits = 7) 
df_train = df_train.reset_index(drop=True)
df_train['fold'] = -1
for fold, (train_idx, val_idx) in enumerate(kf.split(df_train, y = df_train.video_id.tolist(), groups=df_train.sequence)):
    df_train.loc[val_idx, 'fold'] = fold

df_train.head(5)
# Out:
#    video_id  sequence  video_frame  sequence_frame image_id  \
# 0         0     40258           16              16     0-16
# 1         0     40258           17              17     0-17
# 2         0     40258           18              18     0-18
# 3         0     40258           19              19     0-19
# 4         0     40258           20              20     0-20
#
#                                          annotations  num_bbox  \
# 0  [{'x': 559, 'y': 213, 'width': 50, 'height': 32}]         1
# 1  [{'x': 558, 'y': 213, 'width': 50, 'height': 32}]         1
# 2  [{'x': 557, 'y': 213, 'width': 50, 'height': 32}]         1
# 3  [{'x': 556, 'y': 214, 'width': 50, 'height': 32}]         1
# 4  [{'x': 555, 'y': 214, 'width': 50, 'height': 32}]         1
#
#                  bboxes  width  height                           image_path  \
# 0  [[559, 213, 50, 32]]   1280     720  dataset/train_images/video_0/16.jpg
# 1  [[558, 213, 50, 32]]   1280     720  dataset/train_images/video_0/17.jpg
# 2  [[557, 213, 50, 32]]   1280     720  dataset/train_images/video_0/18.jpg
# 3  [[556, 214, 50, 32]]   1280     720  dataset/train_images/video_0/19.jpg
# 4  [[555, 214, 50, 32]]   1280     720  dataset/train_images/video_0/20.jpg
#
#    fold
# 0     5
# 1     5
# 2     5
# 3     5
# 4     5

# %%
HOME_DIR = '' 
DATASET_PATH = 'dataset/images'

# !mkdir {HOME_DIR}dataset
# !mkdir {HOME_DIR}{DATASET_PATH}
# !mkdir {HOME_DIR}{DATASET_PATH}/train2017
# !mkdir {HOME_DIR}{DATASET_PATH}/val2017
# !mkdir {HOME_DIR}{DATASET_PATH}/annotations
# Out:
# mkdir: cannot create directory ‘dataset’: File exists
# mkdir: cannot create directory ‘dataset/images’: File exists
# mkdir: cannot create directory ‘dataset/images/train2017’: File exists
# mkdir: cannot create directory ‘dataset/images/val2017’: File exists
# mkdir: cannot create directory ‘dataset/images/annotations’: File exists

# %%
SELECTED_FOLD = 4

for i in tqdm(range(len(df_train))):
    row = df_train.loc[i]
    if row.fold != SELECTED_FOLD:
        copyfile(f'{row.image_path}', f'{HOME_DIR}{DATASET_PATH}/train2017/{row.image_id}.jpg')
    else:
        copyfile(f'{row.image_path}', f'{HOME_DIR}{DATASET_PATH}/val2017/{row.image_id}.jpg')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=4919.0), HTML(value='')))

# %%
print(f'Number of training files: {len(os.listdir(f"{HOME_DIR}{DATASET_PATH}/train2017/"))}')
print(f'Number of validation files: {len(os.listdir(f"{HOME_DIR}{DATASET_PATH}/val2017/"))}')
# Out:
# Number of training files: 4284
# Number of validation files: 635

# %%
def save_annot_json(json_annotation, filename):
    with open(filename, 'w') as f:
        output_json = json.dumps(json_annotation)
        f.write(output_json)

# %%
annotion_id = 0
def dataset2coco(df, dest_path):
    
    global annotion_id
    
    annotations_json = {
        "info": [],
        "licenses": [],
        "categories": [],
        "images": [],
        "annotations": []
    }
    
    info = {
        "year": "2021",
        "version": "1",
        "description": "COTS dataset - COCO format",
        "contributor": "",
        "url": "https://kaggle.com",
        "date_created": "2021-11-30T15:01:26+00:00"
    }
    annotations_json["info"].append(info)
    
    lic = {
            "id": 1,
            "url": "",
            "name": "Unknown"
        }
    annotations_json["licenses"].append(lic)

    classes = {"id": 0, "name": "starfish", "supercategory": "none"}

    annotations_json["categories"].append(classes)

    
    for ann_row in df.itertuples():
            
        images = {
            "id": ann_row[0],
            "license": 1,
            "file_name": ann_row.image_id + '.jpg',
            "height": ann_row.height,
            "width": ann_row.width,
            "date_captured": "2021-11-30T15:01:26+00:00"
        }
        
        annotations_json["images"].append(images)
        
        bbox_list = ann_row.bboxes
        
        for bbox in bbox_list:
            b_width = bbox[2]
            b_height = bbox[3]
            
            # some boxes in COTS are outside the image height and width
            if (bbox[0] + bbox[2] > 1280):
                b_width = bbox[0] - 1280 
            if (bbox[1] + bbox[3] > 720):
                b_height = bbox[1] - 720 
                
            image_annotations = {
                "id": annotion_id,
                "image_id": ann_row[0],
                "category_id": 0,
                "bbox": [bbox[0], bbox[1], b_width, b_height],
                "area": bbox[2] * bbox[3],
                "segmentation": [],
                "iscrowd": 0
            }
            
            annotion_id += 1
            annotations_json["annotations"].append(image_annotations)
        
        
    print(f"Dataset COTS annotation to COCO json format completed! Files: {len(df)}")
    return annotations_json

# %%
df_train[df_train.fold != SELECTED_FOLD]
# Out:
#       video_id  sequence  video_frame  sequence_frame image_id  \
# 0            0     40258           16              16     0-16
# 1            0     40258           17              17     0-17
# 2            0     40258           18              18     0-18
# 3            0     40258           19              19     0-19
# 4            0     40258           20              20     0-20
# ...        ...       ...          ...             ...      ...
# 4843         2     22643         6488            1125   2-6488
# 4844         2     22643         6489            1126   2-6489
# 4845         2     22643         6490            1127   2-6490
# 4846         2     22643         6491            1128   2-6491
# 4847         2     22643         6492            1129   2-6492
#
#                                             annotations  num_bbox  \
# 0     [{'x': 559, 'y': 213, 'width': 50, 'height': 32}]         1
# 1     [{'x': 558, 'y': 213, 'width': 50, 'height': 32}]         1
# 2     [{'x': 557, 'y': 213, 'width': 50, 'height': 32}]         1
# 3     [{'x': 556, 'y': 214, 'width': 50, 'height': 32}]         1
# 4     [{'x': 555, 'y': 214, 'width': 50, 'height': 32}]         1
# ...                                                 ...       ...
# 4843  [{'x': 194, 'y': 661, 'width': 30, 'height': 37}]         1
# 4844  [{'x': 189, 'y': 662, 'width': 30, 'height': 37}]         1
# 4845  [{'x': 185, 'y': 664, 'width': 30, 'height': 37}]         1
# 4846  [{'x': 179, 'y': 677, 'width': 30, 'height': 37}]         1
# 4847  [{'x': 172, 'y': 694, 'width': 30, 'height': 25}]         1
#
#                     bboxes  width  height  \
# 0     [[559, 213, 50, 32]]   1280     720
# 1     [[558, 213, 50, 32]]   1280     720
# 2     [[557, 213, 50, 32]]   1280     720
# 3     [[556, 214, 50, 32]]   1280     720
# 4     [[555, 214, 50, 32]]   1280     720
# ...                    ...    ...     ...
# 4843  [[194, 661, 30, 37]]   1280     720
# 4844  [[189, 662, 30, 37]]   1280     720
# 4845  [[185, 664, 30, 37]]   1280     720
# 4846  [[179, 677, 30, 37]]   1280     720
# 4847  [[172, 694, 30, 25]]   1280     720
#
#                                  image_path  fold
# 0       dataset/train_images/video_0/16.jpg     5
# 1       dataset/train_images/video_0/17.jpg     5
# 2       dataset/train_images/video_0/18.jpg     5
# 3       dataset/train_images/video_0/19.jpg     5
# 4       dataset/train_images/video_0/20.jpg     5
# ...                                     ...   ...
# 4843  dataset/train_images/video_2/6488.jpg     3
# 4844  dataset/train_images/video_2/6489.jpg     3
# 4845  dataset/train_images/video_2/6490.jpg     3
# 4846  dataset/train_images/video_2/6491.jpg     3
# 4847  dataset/train_images/video_2/6492.jpg     3
#
# [4284 rows x 12 columns]

# %%
# Convert COTS dataset to JSON COCO
train_annot_json = dataset2coco(df_train[df_train.fold != SELECTED_FOLD], f"{HOME_DIR}{DATASET_PATH}/train2017/")
val_annot_json = dataset2coco(df_train[df_train.fold == SELECTED_FOLD], f"{HOME_DIR}{DATASET_PATH}/val2017/")

# Save converted annotations
save_annot_json(train_annot_json, f"{HOME_DIR}{DATASET_PATH}/annotations/train.json")
save_annot_json(val_annot_json, f"{HOME_DIR}{DATASET_PATH}/annotations/valid.json")
# Out:
# Dataset COTS annotation to COCO json format completed! Files: 4284
# Dataset COTS annotation to COCO json format completed! Files: 635

# %%
# train_annot_json

# %%
# val_annot_json

# %%
config_file_template = '''

#!/usr/bin/env python3
# -*- coding:utf-8 -*-
# Copyright (c) Megvii, Inc. and its affiliates.

import os

from yolox.exp import Exp as MyExp


class Exp(MyExp):
    def __init__(self):
        super(Exp, self).__init__()
        self.depth = 1
        self.width = 1
        self.exp_name = os.path.split(os.path.realpath(__file__))[1].split(".")[0]
        self.num_classes = 1
        
        self.data_dir = "dataset/images"
        self.train_ann = "train.json"
        self.val_ann = "valid.json"
        
        self.print_interval = 100
        self.eval_interval = 1
        self.data_num_workers = 4
        self.input_size = (800, 1280)
        self.test_size = (800, 1280)

'''

# %%
PIPELINE_CONFIG_PATH='cots_config.py'

pipeline = Template(config_file_template).substitute(max_epoch = 25)

with open(PIPELINE_CONFIG_PATH, 'w') as f:
    f.write(pipeline)

# %%
# ./yolox/data/datasets/voc_classes.py

voc_cls = '''
VOC_CLASSES = (
  "starfish",
)
'''
with open('./yolox/data/datasets/voc_classes.py', 'w') as f:
    f.write(voc_cls)

# ./yolox/data/datasets/coco_classes.py

coco_cls = '''
COCO_CLASSES = (
  "starfish",
)
'''
with open('./yolox/data/datasets/coco_classes.py', 'w') as f:
    f.write(coco_cls)

# %%
# !cp ./tools/train.py ./

# %%
# !python train.py \
    -f cots_config.py \
    -d 1 \
    -b 4 \
    --fp16 \
    -o \
    -c cots_pretrain/best_ckpt.pth
# Out:
# 2021-12-30 14:53:27 | INFO     | yolox.core.trainer:126 - args: Namespace(batch_size=4, cache=False, ckpt='cots_pretrain/best_ckpt.pth', devices=1, dist_backend='nccl', dist_url=None, exp_file='cots_config.py', experiment_name='cots_config', fp16=True, machine_rank=0, name=None, num_machines=1, occupy=True, opts=[], resume=False, start_epoch=None)
# 2021-12-30 14:53:27 | INFO     | yolox.core.trainer:127 - exp value:
# ╒══════════════════╤═══════════════════╕
# │ keys             │ values            │
# ╞══════════════════╪═══════════════════╡
# │ seed             │ None              │
# ├──────────────────┼───────────────────┤
# │ output_dir       │ './YOLOX_outputs' │
# ├──────────────────┼───────────────────┤
# │ print_interval   │ 100               │
# ├──────────────────┼───────────────────┤
# │ eval_interval    │ 1                 │
# ├──────────────────┼───────────────────┤
# │ num_classes      │ 1                 │
# ├──────────────────┼───────────────────┤
# │ depth            │ 1                 │
# ├──────────────────┼───────────────────┤
# │ width            │ 1                 │
# ├──────────────────┼───────────────────┤
# │ act              │ 'silu'            │
# ├──────────────────┼───────────────────┤
# │ data_num_workers │ 4                 │
# ├──────────────────┼───────────────────┤
# │ input_size       │ (800, 1280)       │
# ├──────────────────┼───────────────────┤
# │ multiscale_range │ 5                 │
# ├──────────────────┼───────────────────┤
# │ data_dir         │ 'dataset/images'  │
# ├──────────────────┼───────────────────┤
# │ train_ann        │ 'train.json'      │
# ├──────────────────┼───────────────────┤
# │ val_ann          │ 'valid.json'      │
# ├──────────────────┼───────────────────┤
# │ mosaic_prob      │ 1.0               │
# ├──────────────────┼───────────────────┤
# │ mixup_prob       │ 1.0               │
# ├──────────────────┼───────────────────┤
# │ hsv_prob         │ 1.0               │
# ├──────────────────┼───────────────────┤
# │ flip_prob        │ 0.5               │
# ├──────────────────┼───────────────────┤
# │ degrees          │ 10.0              │
# ├──────────────────┼───────────────────┤
# │ translate        │ 0.1               │
# ├──────────────────┼───────────────────┤
# │ mosaic_scale     │ (0.1, 2)          │
# ├──────────────────┼───────────────────┤
# │ mixup_scale      │ (0.5, 1.5)        │
# ├──────────────────┼───────────────────┤
# │ shear            │ 2.0               │
# ├──────────────────┼───────────────────┤
# │ enable_mixup     │ True              │
# ├──────────────────┼───────────────────┤
# │ warmup_epochs    │ 5                 │
# ├──────────────────┼───────────────────┤
# │ max_epoch        │ 50                │
# ├──────────────────┼───────────────────┤
# │ warmup_lr        │ 0                 │
# ├──────────────────┼───────────────────┤
# │ basic_lr_per_img │ 0.00015625        │
# ├──────────────────┼───────────────────┤
# │ scheduler        │ 'yoloxwarmcos'    │
# ├──────────────────┼───────────────────┤
# │ no_aug_epochs    │ 2                 │
# ├──────────────────┼───────────────────┤
# │ min_lr_ratio     │ 0.05              │
# ├──────────────────┼───────────────────┤
# │ ema              │ True              │
# ├──────────────────┼───────────────────┤
# │ weight_decay     │ 0.0005            │
# ├──────────────────┼───────────────────┤
# │ momentum         │ 0.9               │
# ├──────────────────┼───────────────────┤
# │ exp_name         │ 'cots_config'     │
# ├──────────────────┼───────────────────┤
# │ test_size        │ (800, 1280)       │
# ├──────────────────┼───────────────────┤
# │ test_conf        │ 0.01              │
# ├──────────────────┼───────────────────┤
# │ nmsthre          │ 0.65              │
# ╘══════════════════╧═══════════════════╛
# 2021-12-30 14:53:27 | INFO     | yolox.core.trainer:133 - Model Summary: Params: 54.15M, Gflops: 388.27
# 2021-12-30 14:53:30 | INFO     | yolox.core.trainer:286 - loading checkpoint for fine tuning
# 2021-12-30 14:53:31 | INFO     | yolox.data.datasets.coco:45 - loading annotations into memory...
# 2021-12-30 14:53:31 | INFO     | yolox.data.datasets.coco:45 - Done (t=0.02s)
# 2021-12-30 14:53:31 | INFO     | pycocotools.coco:88 - creating index...
# 2021-12-30 14:53:31 | INFO     | pycocotools.coco:88 - index created!
# 2021-12-30 14:53:31 | INFO     | yolox.core.trainer:151 - init prefetcher, this might take one minute or less...
# 2021-12-30 14:53:38 | INFO     | yolox.data.datasets.coco:45 - loading annotations into memory...
# 2021-12-30 14:53:38 | INFO     | yolox.data.datasets.coco:45 - Done (t=0.00s)
# 2021-12-30 14:53:38 | INFO     | pycocotools.coco:88 - creating index...
# 2021-12-30 14:53:38 | INFO     | pycocotools.coco:88 - index created!
# 2021-12-30 14:53:39.100083: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /media/ken/01D7D016D3925700/ubuntu/anaconda/lib/python3.7/site-packages/cv2/../../lib64:/media/ken/01D7D016D3925700/ubuntu/anaconda/lib/python3.7/site-packages/cv2/../../lib64:
# 2021-12-30 14:53:39.100107: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-12-30 14:53:43 | INFO     | yolox.core.trainer:179 - Training start...
# 2021-12-30 14:53:43 | INFO     | yolox.core.trainer:180 -
# YOLOX(
#   (backbone): YOLOPAFPN(
#     (backbone): CSPDarknet(
#       (stem): Focus(
#         (conv): BaseConv(
#           (conv): Conv2d(12, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (dark2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark3): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (4): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (5): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (6): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (7): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (8): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark4): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (4): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (5): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (6): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (7): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (8): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark5): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1024, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): SPPBottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): ModuleList(
#             (0): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#             (1): MaxPool2d(kernel_size=9, stride=1, padding=4, dilation=1, ceil_mode=False)
#             (2): MaxPool2d(kernel_size=13, stride=1, padding=6, dilation=1, ceil_mode=False)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(1024, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(1024, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     (upsample): Upsample(scale_factor=2.0, mode=nearest)
#     (lateral_conv0): BaseConv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (reduce_conv1): BaseConv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv2): BaseConv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv1): BaseConv(
#       (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(1024, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (head): YOLOXHead(
#     (cls_convs): ModuleList(
#       (0): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (reg_convs): ModuleList(
#       (0): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (cls_preds): ModuleList(
#       (0): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (reg_preds): ModuleList(
#       (0): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (obj_preds): ModuleList(
#       (0): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (stems): ModuleList(
#       (0): BaseConv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): BaseConv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): BaseConv(
#         (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.01, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (l1_loss): L1Loss()
#     (bcewithlog_loss): BCEWithLogitsLoss()
#     (iou_loss): IOUloss()
#   )
# )
# 2021-12-30 14:53:43 | INFO     | yolox.core.trainer:188 - ---> start train epoch1
# 2021-12-30 14:53:44 | INFO     | yolox.core.trainer:184 - Training of experiment is done and the best AP is 0.00
# 2021-12-30 14:53:44 | ERROR    | yolox.core.launch:98 - An error has been caught in function 'launch', process 'MainProcess' (8981), thread 'MainThread' (139666834601792):
# Traceback (most recent call last):
#
#   File "train.py", line 132, in <module>
#     args=(exp, args),
#           │    └ Namespace(batch_size=4, cache=False, ckpt='cots_pretrain/best_ckpt.pth', devices=1, dist_backend='nccl', dist_url=None, exp_f...
#           └ ╒══════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════...
#
# > File "/media/ken/01D7D016D3925700/kaggle/YOLOX/yolox/core/launch.py", line 98, in launch
#     main_func(*args)
#     │          └ (╒══════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════════...
#     └ <function main at 0x7f0653547b00>
#
#   File "train.py", line 110, in main
#     trainer.train()
#     │       └ <function Trainer.train at 0x7f0653556290>
#     └ <yolox.core.trainer.Trainer object at 0x7f0652bd5390>
#
#   File "/media/ken/01D7D016D3925700/kaggle/YOLOX/yolox/core/trainer.py", line 72, in train
#     self.train_in_epoch()
#     │    └ <function Trainer.train_in_epoch at 0x7f0642196680>
#     └ <yolox.core.trainer.Trainer object at 0x7f0652bd5390>
#
#   File "/media/ken/01D7D016D3925700/kaggle/YOLOX/yolox/core/trainer.py", line 81, in train_in_epoch
#     self.train_in_iter()
#     │    └ <function Trainer.train_in_iter at 0x7f06421964d0>
#     └ <yolox.core.trainer.Trainer object at 0x7f0652bd5390>
#
#   File "/media/ken/01D7D016D3925700/kaggle/YOLOX/yolox/core/trainer.py", line 87, in train_in_iter
#     self.train_one_iter()
#     │    └ <function Trainer.train_one_iter at 0x7f064111dd40>
#     └ <yolox.core.trainer.Trainer object at 0x7f0652bd5390>
#
#   File "/media/ken/01D7D016D3925700/kaggle/YOLOX/yolox/core/trainer.py", line 101, in train_one_iter
#     outputs = self.model(inps, targets)
#               │    │     │     └ tensor([[[   0.0000,  860.5000,  175.2500,  100.2500,  112.9375],
#               │    │     │                [   0.0000,    0.0000,    0.0000,    0.0000,    0....
#               │    │     └ <unprintable Tensor object>
#               │    └ YOLOX(
#               │        (backbone): YOLOPAFPN(
#               │          (backbone): CSPDarknet(
#               │            (stem): Focus(
#               │              (conv): BaseConv(
#               │                (conv): ...
#               └ <yolox.core.trainer.Trainer object at 0x7f0652bd5390>
#
#   File "/media/ken/01D7D016D3925700/ubuntu/anaconda/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#              │    │        │        └ {}
#              │    │        └ <unprintable tuple object>
#              │    └ <function YOLOX.forward at 0x7f0665c9cef0>
#              └ YOLOX(
#                  (backbone): YOLOPAFPN(
#                    (backbone): CSPDarknet(
#                      (stem): Focus(
#                        (conv): BaseConv(
#                          (conv): ...
#
#   File "/media/ken/01D7D016D3925700/kaggle/YOLOX/yolox/models/yolox.py", line 30, in forward
#     fpn_outs = self.backbone(x)
#                │             └ <unprintable Tensor object>
#                └ YOLOX(
#                    (backbone): YOLOPAFPN(
#                      (backbone): CSPDarknet(
#                        (stem): Focus(
#                          (conv): BaseConv(
#                            (conv): ...
#
#   File "/media/ken/01D7D016D3925700/ubuntu/anaconda/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#              │    │        │        └ {}
#              │    │        └ <unprintable tuple object>
#              │    └ <function YOLOPAFPN.forward at 0x7f0665c9cc20>
#              └ YOLOPAFPN(
#                  (backbone): CSPDarknet(
#                    (stem): Focus(
#                      (conv): BaseConv(
#                        (conv): Conv2d(12, 64, kernel_size=(3...
#
#   File "/media/ken/01D7D016D3925700/kaggle/YOLOX/yolox/models/yolo_pafpn.py", line 93, in forward
#     out_features = self.backbone(input)
#                    │             └ <unprintable Tensor object>
#                    └ YOLOPAFPN(
#                        (backbone): CSPDarknet(
#                          (stem): Focus(
#                            (conv): BaseConv(
#                              (conv): Conv2d(12, 64, kernel_size=(3...
#
#   File "/media/ken/01D7D016D3925700/ubuntu/anaconda/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#              │    │        │        └ {}
#              │    │        └ <unprintable tuple object>
#              │    └ <function CSPDarknet.forward at 0x7f0665c92680>
#              └ CSPDarknet(
#                  (stem): Focus(
#                    (conv): BaseConv(
#                      (conv): Conv2d(12, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1...
#
#   File "/media/ken/01D7D016D3925700/kaggle/YOLOX/yolox/models/darknet.py", line 173, in forward
#     x = self.dark3(x)
#         │          └ <unprintable Tensor object>
#         └ CSPDarknet(
#             (stem): Focus(
#               (conv): BaseConv(
#                 (conv): Conv2d(12, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1...
#
#   File "/media/ken/01D7D016D3925700/ubuntu/anaconda/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#              │    │        │        └ {}
#              │    │        └ <unprintable tuple object>
#              │    └ <function Sequential.forward at 0x7f06537a3f80>
#              └ Sequential(
#                  (0): BaseConv(
#                    (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                    ...
#   File "/media/ken/01D7D016D3925700/ubuntu/anaconda/lib/python3.7/site-packages/torch/nn/modules/container.py", line 117, in forward
#     input = module(input)
#             │      └ <unprintable Tensor object>
#             └ CSPLayer(
#                 (conv1): BaseConv(
#                   (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNor...
#   File "/media/ken/01D7D016D3925700/ubuntu/anaconda/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#              │    │        │        └ {}
#              │    │        └ <unprintable tuple object>
#              │    └ <function CSPLayer.forward at 0x7f0665c92e60>
#              └ CSPLayer(
#                  (conv1): BaseConv(
#                    (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                    (bn): BatchNor...
#
#   File "/media/ken/01D7D016D3925700/kaggle/YOLOX/yolox/models/network_blocks.py", line 183, in forward
#     x_1 = self.m(x_1)
#           │      └ <unprintable Tensor object>
#           └ CSPLayer(
#               (conv1): BaseConv(
#                 (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNor...
#
#   File "/media/ken/01D7D016D3925700/ubuntu/anaconda/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#              │    │        │        └ {}
#              │    │        └ <unprintable tuple object>
#              │    └ <function Sequential.forward at 0x7f06537a3f80>
#              └ Sequential(
#                  (0): Bottleneck(
#                    (conv1): BaseConv(
#                      (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=...
#   File "/media/ken/01D7D016D3925700/ubuntu/anaconda/lib/python3.7/site-packages/torch/nn/modules/container.py", line 117, in forward
#     input = module(input)
#             │      └ <unprintable Tensor object>
#             └ Bottleneck(
#                 (conv1): BaseConv(
#                   (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchN...
#   File "/media/ken/01D7D016D3925700/ubuntu/anaconda/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#              │    │        │        └ {}
#              │    │        └ <unprintable tuple object>
#              │    └ <function Bottleneck.forward at 0x7f0665c92b00>
#              └ Bottleneck(
#                  (conv1): BaseConv(
#                    (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                    (bn): BatchN...
#
#   File "/media/ken/01D7D016D3925700/kaggle/YOLOX/yolox/models/network_blocks.py", line 98, in forward
#     y = self.conv2(self.conv1(x))
#         │          │          └ <unprintable Tensor object>
#         │          └ Bottleneck(
#         │              (conv1): BaseConv(
#         │                (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         │                (bn): BatchN...
#         └ Bottleneck(
#             (conv1): BaseConv(
#               (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchN...
#
#   File "/media/ken/01D7D016D3925700/ubuntu/anaconda/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#              │    │        │        └ {}
#              │    │        └ <unprintable tuple object>
#              │    └ <function BaseConv.forward at 0x7f0665c92830>
#              └ BaseConv(
#                  (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                  (bn): BatchNorm2d(128, ...
#
#   File "/media/ken/01D7D016D3925700/kaggle/YOLOX/yolox/models/network_blocks.py", line 51, in forward
#     return self.act(self.bn(self.conv(x)))
#            │        │       │         └ <unprintable Tensor object>
#            │        │       └ BaseConv(
#            │        │           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            │        │           (bn): BatchNorm2d(128, ...
#            │        └ BaseConv(
#            │            (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            │            (bn): BatchNorm2d(128, ...
#            └ BaseConv(
#                (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                (bn): BatchNorm2d(128, ...
#
#   File "/media/ken/01D7D016D3925700/ubuntu/anaconda/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#              │    │        │        └ {}
#              │    │        └ <unprintable tuple object>
#              │    └ <function Conv2d.forward at 0x7f06537e6a70>
#              └ Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   File "/media/ken/01D7D016D3925700/ubuntu/anaconda/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 423, in forward
#     return self._conv_forward(input, self.weight)
#            │    │             │      └ Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            │    │             └ <unprintable Tensor object>
#            │    └ <function Conv2d._conv_forward at 0x7f06537e69e0>
#            └ Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   File "/media/ken/01D7D016D3925700/ubuntu/anaconda/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 420, in _conv_forward
#     self.padding, self.dilation, self.groups)
#     │    │        │    │         │    └ 1
#     │    │        │    │         └ Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     │    │        │    └ (1, 1)
#     │    │        └ Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     │    └ (1, 1)
#     └ Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#
# RuntimeError: CUDA out of memory. Tried to allocate 16.00 MiB (GPU 0; 3.82 GiB total capacity; 2.47 GiB already allocated; 25.25 MiB free; 2.52 GiB reserved in total by PyTorch)
