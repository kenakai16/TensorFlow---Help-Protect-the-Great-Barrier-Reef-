# %%
# arrange an instance segmentation model for test
from sahi.utils.yolov5 import (
    download_yolov5s6_model,
)

# import required functions, classes
from sahi.model import Yolov5DetectionModel
from sahi.utils.cv import read_image
from sahi.utils.file import download_from_url
from sahi.predict import get_prediction, get_sliced_prediction, predict
from IPython.display import Image

# %%
# download YOLOV5S6 model to 'models/yolov5s6.pt'
yolov5_model_path = 'yolov5s6.pt'

# %%
download_yolov5s6_model(destination_path=yolov5_model_path)

# %%
detection_model = Yolov5DetectionModel(
    model_path=yolov5_model_path,
    confidence_threshold=0.3,
    device="cpu", # or 'cuda:0'
)
# Out:
# 01/16/2022 15:06:50 - INFO - numexpr.utils -   NumExpr defaulting to 8 threads.
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -
#                  from  n    params  module                                  arguments
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -     0                -1  1      3520  yolov5.models.common.Focus              [3, 32, 3]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -     1                -1  1     18560  yolov5.models.common.Conv               [32, 64, 3, 2]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -     2                -1  1     18816  yolov5.models.common.C3                 [64, 64, 1]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -     3                -1  1     73984  yolov5.models.common.Conv               [64, 128, 3, 2]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -     4                -1  3    156928  yolov5.models.common.C3                 [128, 128, 3]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -     5                -1  1    295424  yolov5.models.common.Conv               [128, 256, 3, 2]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -     6                -1  3    625152  yolov5.models.common.C3                 [256, 256, 3]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -     7                -1  1    885504  yolov5.models.common.Conv               [256, 384, 3, 2]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -     8                -1  1    665856  yolov5.models.common.C3                 [384, 384, 1]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -     9                -1  1   1770496  yolov5.models.common.Conv               [384, 512, 3, 2]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    10                -1  1    656896  yolov5.models.common.SPP                [512, 512, [3, 5, 7]]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    11                -1  1   1182720  yolov5.models.common.C3                 [512, 512, 1, False]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    12                -1  1    197376  yolov5.models.common.Conv               [512, 384, 1, 1]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    14           [-1, 8]  1         0  yolov5.models.common.Concat             [1]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    15                -1  1    813312  yolov5.models.common.C3                 [768, 384, 1, False]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    16                -1  1     98816  yolov5.models.common.Conv               [384, 256, 1, 1]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    17                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    18           [-1, 6]  1         0  yolov5.models.common.Concat             [1]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    19                -1  1    361984  yolov5.models.common.C3                 [512, 256, 1, False]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    20                -1  1     33024  yolov5.models.common.Conv               [256, 128, 1, 1]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    21                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    22           [-1, 4]  1         0  yolov5.models.common.Concat             [1]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    23                -1  1     90880  yolov5.models.common.C3                 [256, 128, 1, False]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    24                -1  1    147712  yolov5.models.common.Conv               [128, 128, 3, 2]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    25          [-1, 20]  1         0  yolov5.models.common.Concat             [1]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    26                -1  1    296448  yolov5.models.common.C3                 [256, 256, 1, False]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    27                -1  1    590336  yolov5.models.common.Conv               [256, 256, 3, 2]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    28          [-1, 16]  1         0  yolov5.models.common.Concat             [1]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    29                -1  1    715008  yolov5.models.common.C3                 [512, 384, 1, False]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    30                -1  1   1327872  yolov5.models.common.Conv               [384, 384, 3, 2]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    31          [-1, 12]  1         0  yolov5.models.common.Concat             [1]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    32                -1  1   1313792  yolov5.models.common.C3                 [768, 512, 1, False]
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -    33  [23, 26, 29, 32]  1    327420  yolov5.models.yolo.Detect               [80, [[19, 27, 44, 40, 38, 94], [96, 68, 86, 152, 180, 137], [140, 301, 303, 264, 238, 542], [436, 615, 739, 380, 925, 792]], [128, 256, 384, 512]]
# 01/16/2022 15:06:51 - INFO - yolov5.utils.torch_utils -   Model Summary: 368 layers, 12667836 parameters, 12667836 gradients, 17.4 GFLOPs
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -
# 01/16/2022 15:06:51 - INFO - yolov5.models.yolo -   Adding AutoShape...

# %%
result = get_prediction("small-vehicles1.jpeg", detection_model)

# %%
result = get_prediction(read_image("small-vehicles1.jpeg"), detection_model)

# %%
result.export_visuals(export_dir="demo_data/")

Image("demo_data/prediction_visual.png")

# %%
result = get_sliced_prediction(
    "small-vehicles1.jpeg",
    detection_model,
    slice_height = 256,
    slice_width = 256,
    overlap_height_ratio = 0.2,
    overlap_width_ratio = 0.2
)
# Out:
# Performing prediction on 15 number of slices.

# %%
result.export_visuals(export_dir="demo_data/")

Image("demo_data/prediction_visual.png")
